# %%
# f = open ("demo.txt","r")
f = open ("demo.txt", "w")
# data = f.read()
# print (data)
# print (type(data))
# line2 = f.readline()
# print(line2)

f.write("we love each other so much")



f.close()
