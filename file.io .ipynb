# %%
f = open ("demo.txt","r")
data = f.read()


print (data)
print (type(data))

line2 = f.readline()
print(line2)

f.close()
# Out:
# my wife name is umme habiba islam rupa
# my name is nizam uddin shuvo
# <class 'str'>
